# %% [markdown]
# # 01 — Load the Data
#
# Ingest raw CSV data from two sources into parquet (idempotent — skips if already built) and load as DataFrames.
#
# | Source | Library | Raw dir | DB dir |
# |--------|---------|---------|--------|
# | Check Expert (체크전문가) | `utils.chkxp_ingest` | `data/raw/chkxp/` | `data/db/chkxp/` |
# | FnGuide DataGuide 6 | `fn_dg6_ingest` | `data/raw/fnguide/` | `data/db/fnguide/` |

# %%
from pathlib import Path

import fn_dg6_ingest
from utils.chkxp_ingest import open as chkxp_open

# %% [markdown]
# ## Raw CSV paths
#
# All Check Expert files under `data/raw/chkxp/` (excluding `stock_lob/`).

# %%
RAW_DIR = Path("../data/raw/chkxp")
DB_DIR  = Path("../data/db/chkxp")

DATASETS = {
    "etf_1m":  RAW_DIR / "chkxp_etf(kodex200)_(1m)_ohlcvNAV.csv",
    "etf_10s": RAW_DIR / "chkxp_etf(kodex200)_(10s)_ohlcvNAVlob.csv",
    "kp200":   RAW_DIR / "kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20260207).csv",
    "ktb":     RAW_DIR / "ktb_(3)(10)_(fut)(spread)(2nd)_(1m)_from(20200101)_to(20260207).csv",
}

# %% [markdown]
# ## Ingest (idempotent)
#
# `chkxp_open()` checks if the parquet output already exists. If so, it skips the build and returns a `Dataset` handle instantly.

# %%
ds = {}
for name, csv_path in DATASETS.items():
    output_dir = DB_DIR / csv_path.stem
    ds[name] = chkxp_open(str(csv_path), output_dir=str(output_dir))
    info = ds[name].describe()
    print(f"{name:10s}  {info.format_name:15s}  {info.frequency:4s}  {info.shape[0]:>10,} rows  entities={info.entities}")
# Out:
# etf_1m      single_entity    1M        23,800 rows  entities=['KODEX 200']
# etf_10s     single_entity    10S       49,200 rows  entities=['KODEX 200']
# kp200       multi_entity     1M       786,800 rows  entities=['KOSPI200 선물 2603', 'K200 스프레드 6366', 'KOSPI200 선물 2606', 'MINI KOSPI200 선물 2602', 'MINI K200 스프레드 6263', 'V-KOSPI200 선물 2602', 'V-KOSPI200 스프레드 6263']
# ktb         multi_entity     1M     1,513,800 rows  entities=['(N)KTB3 선물 2603', '(N)KTB3 스프레드 6366', '(N)KTB3 선물 2606', '(N)KTB10 선물 2603', '(N)KTB10 스프레드 6366', '(N)KTB10 선물 2606']

# %% [markdown]
# ## Load full datasets

# %%
df_etf_1m  = ds["etf_1m"].load()
df_etf_10s = ds["etf_10s"].load()
df_kp200   = ds["kp200"].load()
df_ktb     = ds["ktb"].load()

# %% [markdown]
# ## Quick preview

# %%
df_etf_1m.head()
# Out:
#              datetime     entity entity_code  Intra시가  Intra고가  Intra저가  \
# 0 2025-11-11 09:01:00  KODEX 200  069500*001  58450.0  58720.0  58450.0
# 1 2025-11-11 09:02:00  KODEX 200  069500*001  58720.0  58810.0  58625.0
# 2 2025-11-11 09:03:00  KODEX 200  069500*001  58660.0  58770.0  58605.0
# 3 2025-11-11 09:04:00  KODEX 200  069500*001  58740.0  58815.0  58675.0
# 4 2025-11-11 09:05:00  KODEX 200  069500*001  58695.0  58810.0  58685.0
#
#    Intra종가  Intra매도거래량  Intra매수거래량  IntraETP기초지수  Intra장중지표가치(iNAV/iIV)시가  \
# 0  58705.0     40040.0    145573.0        586.33                 58501.73
# 1  58660.0     96993.0    106907.0        586.35                 58773.38
# 2  58745.0     70163.0     62650.0        586.63                 58779.26
# 3  58700.0     82122.0     48424.0        586.40                 58823.43
# 4  58800.0     38236.0     26858.0        587.43                 58780.09
#
#    Intra장중지표가치(iNAV/iIV)고가  Intra장중지표가치(iNAV/iIV)저가  Intra장중지표가치(iNAV/iIV)종가  \
# 0                 58776.20                 58487.99                 58773.38
# 1                 58838.48                 58719.31                 58779.26
# 2                 58874.70                 58709.60                 58823.43
# 3                 58916.00                 58767.96                 58780.09
# 4                 58890.11                 58776.59                 58881.69
#
#    IntraETP괴리율  Intra추적오차율
# 0        -0.11        0.01
# 1        -0.20        0.02
# 2        -0.14        0.04
# 3        -0.14        0.01
# 4        -0.13        0.00

# %%
df_kp200.head()
# Out:
#              datetime                 entity  entity_code  Intra시가  Intra고가  \
# 0 2025-01-02 09:46:00         K200 스프레드 6366  K2FS020*005    -0.80    -0.80
# 1 2025-01-02 09:46:00       KOSPI200 선물 2603  K2FA020*005   317.70   318.65
# 2 2025-01-02 09:46:00       KOSPI200 선물 2606  K2FB020*005   316.75   317.80
# 3 2025-01-02 09:46:00    MINI K200 스프레드 6263  M2FS020*103     0.94     0.94
# 4 2025-01-02 09:46:00  MINI KOSPI200 선물 2602  M2FA020*103   316.88   317.94
#
#    Intra저가  Intra종가     Intra거래대금
# 0    -0.85    -0.85  1.271112e+09
# 1   317.55   318.45  2.707162e+11
# 2   316.75   317.80  4.360162e+09
# 3     0.94     0.94  0.000000e+00
# 4   316.80   317.76  1.534206e+10

# %%
df_ktb.head()
# Out:
#              datetime              entity  entity_code  Intra시가  Intra고가  \
# 0 2023-07-12 09:01:00    (N)KTB10 선물 2603  KXFA020*016   110.15   110.22
# 1 2023-07-12 09:01:00    (N)KTB10 선물 2606  KXFB020*016   110.14   110.14
# 2 2023-07-12 09:01:00  (N)KTB10 스프레드 6366  XBFS020*016    -0.27    -0.27
# 3 2023-07-12 09:01:00     (N)KTB3 선물 2603  KBFA020*017   103.56   103.56
# 4 2023-07-12 09:01:00     (N)KTB3 선물 2606  KBFB020*017   103.58   103.58
#
#    Intra저가  Intra종가     Intra거래대금
# 0   110.05   110.07  1.670787e+11
# 1   110.14   110.14  0.000000e+00
# 2    -0.27    -0.27  0.000000e+00
# 3   103.54   103.55  3.967138e+11
# 4   103.58   103.58  0.000000e+00

# %% [markdown]
# ## Filtered loading examples
#
# `load()` supports entity, item (column), and date-range filters — all pushed down to PyArrow so only the needed data is read from disk.

# %%
# KP200 front-month futures only, OHLC columns, Jan 2025
ds["kp200"].load(
    entities=["KOSPI200 선물 2603"],
    items=["Intra시가", "Intra고가", "Intra저가", "Intra종가"],
    date_from="2025-01-01",
    date_to="2025-01-31",
)
# Out:
#                 datetime            entity  entity_code  Intra시가  Intra고가  \
# 0    2025-01-02 09:46:00  KOSPI200 선물 2603  K2FA020*005   317.70   318.65
# 1    2025-01-02 09:47:00  KOSPI200 선물 2603  K2FA020*005   318.40   318.40
# 2    2025-01-02 09:48:00  KOSPI200 선물 2603  K2FA020*005   318.05   318.15
# 3    2025-01-02 09:49:00  KOSPI200 선물 2603  K2FA020*005   317.40   317.55
# 4    2025-01-02 09:50:00  KOSPI200 선물 2603  K2FA020*005   317.45   317.50
# ...                  ...               ...          ...      ...      ...
# 7075 2025-01-24 15:41:00  KOSPI200 선물 2603  K2FA020*005   336.10   336.10
# 7076 2025-01-24 15:42:00  KOSPI200 선물 2603  K2FA020*005   336.10   336.10
# 7077 2025-01-24 15:43:00  KOSPI200 선물 2603  K2FA020*005   336.10   336.10
# 7078 2025-01-24 15:44:00  KOSPI200 선물 2603  K2FA020*005   336.10   336.10
# 7079 2025-01-24 15:45:00  KOSPI200 선물 2603  K2FA020*005   336.10   336.10
#
#       Intra저가  Intra종가
# 0      317.55   318.45
# 1      317.75   318.00
# 2      317.40   317.40
# 3      317.20   317.50
# 4      317.30   317.30
# ...       ...      ...
# 7075   336.10   336.10
# 7076   336.10   336.10
# 7077   336.10   336.10
# 7078   336.10   336.10
# 7079   335.85   335.85
#
# [7080 rows x 7 columns]

# %%
# ETF 1-min iNAV close vs ETF close
ds["etf_1m"].load(
    items=["Intra종가", "Intra장중지표가치(iNAV/iIV)종가", "IntraETP괴리율"],
)
# Out:
#                  datetime     entity entity_code  Intra종가  \
# 0     2025-11-11 09:01:00  KODEX 200  069500*001  58705.0
# 1     2025-11-11 09:02:00  KODEX 200  069500*001  58660.0
# 2     2025-11-11 09:03:00  KODEX 200  069500*001  58745.0
# 3     2025-11-11 09:04:00  KODEX 200  069500*001  58700.0
# 4     2025-11-11 09:05:00  KODEX 200  069500*001  58800.0
# ...                   ...        ...         ...      ...
# 23795                 NaT  KODEX 200  069500*001      NaN
# 23796                 NaT  KODEX 200  069500*001      NaN
# 23797                 NaT  KODEX 200  069500*001      NaN
# 23798                 NaT  KODEX 200  069500*001      NaN
# 23799                 NaT  KODEX 200  069500*001      NaN
#
#        Intra장중지표가치(iNAV/iIV)종가  IntraETP괴리율
# 0                     58773.38        -0.11
# 1                     58779.26        -0.20
# 2                     58823.43        -0.14
# 3                     58780.09        -0.14
# 4                     58881.69        -0.13
# ...                        ...          ...
# 23795                      NaN          NaN
# 23796                      NaN          NaN
# 23797                      NaN          NaN
# 23798                      NaN          NaN
# 23799                      NaN          NaN
#
# [23800 rows x 6 columns]

# %% [markdown]
# ## Metadata / lineage

# %%
ds["kp200"].load_meta()
# Out:
#                                           source_file  \
# 0   kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 1   kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 2   kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 3   kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 4   kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 5   kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 6   kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 7   kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 8   kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 9   kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 10  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 11  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 12  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 13  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 14  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 15  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 16  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 17  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 18  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 19  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 20  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 21  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 22  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 23  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 24  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 25  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 26  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 27  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 28  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 29  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 30  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 31  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 32  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 33  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
# 34  kp200_(fut)(mini)(v)_(1m)_from(20250101)_to(20...
#
#                                           source_hash detected_format  \
# 0   10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 1   10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 2   10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 3   10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 4   10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 5   10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 6   10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 7   10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 8   10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 9   10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 10  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 11  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 12  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 13  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 14  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 15  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 16  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 17  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 18  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 19  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 20  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 21  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 22  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 23  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 24  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 25  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 26  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 27  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 28  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 29  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 30  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 31  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 32  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 33  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
# 34  10117c64a23608f104e056c65a04d79cae98982a446c46...    multi_entity
#
#               entity_name  entity_code item_code field_code  item_name  \
# 0        KOSPI200 선물 2603  K2FA020*005     20005     F20005    Intra시가
# 1        KOSPI200 선물 2603  K2FA020*005     20006     F20006    Intra고가
# 2        KOSPI200 선물 2603  K2FA020*005     20007     F20007    Intra저가
# 3        KOSPI200 선물 2603  K2FA020*005     20008     F20008    Intra종가
# 4        KOSPI200 선물 2603  K2FA020*005     20011     F20011  Intra거래대금
# 5          K200 스프레드 6366  K2FS020*005     20005     F20005    Intra시가
# 6          K200 스프레드 6366  K2FS020*005     20006     F20006    Intra고가
# 7          K200 스프레드 6366  K2FS020*005     20007     F20007    Intra저가
# 8          K200 스프레드 6366  K2FS020*005     20008     F20008    Intra종가
# 9          K200 스프레드 6366  K2FS020*005     20011     F20011  Intra거래대금
# 10       KOSPI200 선물 2606  K2FB020*005     20005     F20005    Intra시가
# 11       KOSPI200 선물 2606  K2FB020*005     20006     F20006    Intra고가
# 12       KOSPI200 선물 2606  K2FB020*005     20007     F20007    Intra저가
# 13       KOSPI200 선물 2606  K2FB020*005     20008     F20008    Intra종가
# 14       KOSPI200 선물 2606  K2FB020*005     20011     F20011  Intra거래대금
# 15  MINI KOSPI200 선물 2602  M2FA020*103     20005     F20005    Intra시가
# 16  MINI KOSPI200 선물 2602  M2FA020*103     20006     F20006    Intra고가
# 17  MINI KOSPI200 선물 2602  M2FA020*103     20007     F20007    Intra저가
# 18  MINI KOSPI200 선물 2602  M2FA020*103     20008     F20008    Intra종가
# 19  MINI KOSPI200 선물 2602  M2FA020*103     20011     F20011  Intra거래대금
# 20    MINI K200 스프레드 6263  M2FS020*103     20005     F20005    Intra시가
# 21    MINI K200 스프레드 6263  M2FS020*103     20006     F20006    Intra고가
# 22    MINI K200 스프레드 6263  M2FS020*103     20007     F20007    Intra저가
# 23    MINI K200 스프레드 6263  M2FS020*103     20008     F20008    Intra종가
# 24    MINI K200 스프레드 6263  M2FS020*103     20011     F20011  Intra거래대금
# 25     V-KOSPI200 선물 2602  VIFA020*099     20005     F20005    Intra시가
# 26     V-KOSPI200 선물 2602  VIFA020*099     20006     F20006    Intra고가
# 27     V-KOSPI200 선물 2602  VIFA020*099     20007     F20007    Intra저가
# 28     V-KOSPI200 선물 2602  VIFA020*099     20008     F20008    Intra종가
# 29     V-KOSPI200 선물 2602  VIFA020*099     20011     F20011  Intra거래대금
# 30   V-KOSPI200 스프레드 6263  VIFS020*099     20005     F20005    Intra시가
# 31   V-KOSPI200 스프레드 6263  VIFS020*099     20006     F20006    Intra고가
# 32   V-KOSPI200 스프레드 6263  VIFS020*099     20007     F20007    Intra저가
# 33   V-KOSPI200 스프레드 6263  VIFS020*099     20008     F20008    Intra종가
# 34   V-KOSPI200 스프레드 6263  VIFS020*099     20011     F20011  Intra거래대금
#
#    frequency period_start period_end                      processed_at
# 0         1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 1         1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 2         1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 3         1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 4         1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 5         1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 6         1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 7         1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 8         1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 9         1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 10        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 11        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 12        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 13        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 14        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 15        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 16        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 17        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 18        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 19        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 20        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 21        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 22        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 23        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 24        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 25        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 26        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 27        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 28        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 29        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 30        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 31        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 32        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 33        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00
# 34        1M     20250101   20260207  2026-02-12T07:16:08.660412+00:00

# %% [markdown]
# ---
#
# # FnGuide DataGuide 6
#
# Daily equity data (OHLCV, consensus, ETF constituents) from `data/raw/fnguide/`.

# %%
FN_RAW_DIR = Path("../data/raw/fnguide")
FN_DB_DIR  = Path("../data/db/fnguide")

FN_DATASETS = {
    "ohlcv":      FN_RAW_DIR / "dataguide_kse+kosdaq_ohlcv_from(20160101)_to(20260207).csv",
    "consensus":  FN_RAW_DIR / "dataguide_kse+kosdaq_sales-consensus_from(20180101)_to(20260207).csv",
    "etf_const":  FN_RAW_DIR / "dataguide_etfconst(kodex200)_from(20250101)_to(20260207).csv",
}

# %% [markdown]
# ## Ingest FnGuide (idempotent)
#
# `fn_dg6_ingest.open()` auto-detects the CSV format, builds parquet + `_meta`, and skips if output already exists. The large OHLCV file (~350 MB) takes a few minutes on first run.

# %%
fn_ds = {}
for name, csv_path in FN_DATASETS.items():
    output_dir = FN_DB_DIR / csv_path.stem
    fn_ds[name] = fn_dg6_ingest.open(str(csv_path), output_dir=str(output_dir))
    info = fn_ds[name].describe()
    print(f"{name:12s}  {info.format_name:20s}  {info.shape}  entities={info.entities}")
# Out:
# ohlcv         timeseries_wide       {'default': (7613009, 9)}  entities=4071
# consensus     timeseries_wide       {'default': (4913310, 13)}  entities=4071
# etf_const     misc_etf              {'default': (53836, 8)}  entities=0

# %% [markdown]
# ## Load FnGuide datasets

# %%
df_ohlcv     = fn_ds["ohlcv"].load()
df_consensus = fn_ds["consensus"].load()
df_etf_const = fn_ds["etf_const"].load()

# %% [markdown]
# ## Quick preview

# %%
df_ohlcv.head()
# Out:
#         코드   코드명        date  수정시가(원)  수정고가(원)  수정저가(원)  수정주가(원)    거래량(주)  \
# 0  A000020  동화약품  2015-12-30   8180.0   8180.0   8020.0   8140.0  166761.0
# 1  A000020  동화약품  2016-01-04   8130.0   8150.0   7920.0   8140.0  281440.0
# 2  A000020  동화약품  2016-01-05   8040.0   8250.0   8000.0   8190.0  243179.0
# 3  A000020  동화약품  2016-01-06   8200.0   8590.0   8110.0   8550.0  609906.0
# 4  A000020  동화약품  2016-01-07   8470.0   8690.0   8190.0   8380.0  704752.0
#
#         거래대금(원)
# 0  1.348911e+09
# 1  2.265829e+09
# 2  1.981977e+09
# 3  5.129946e+09
# 4  5.919556e+09

# %%
df_consensus.head()
# Out:
#         코드   코드명        date  추정기관수  최근기업리포트발간일  매출액(원)  매출액(최고)(원)  \
# 0  A000020  동화약품  2017-12-28    NaN  20170221.0     NaN         NaN
# 1  A000020  동화약품  2018-01-02    NaN  20170221.0     NaN         NaN
# 2  A000020  동화약품  2018-01-03    NaN  20170221.0     NaN         NaN
# 3  A000020  동화약품  2018-01-04    NaN  20170221.0     NaN         NaN
# 4  A000020  동화약품  2018-01-05    NaN  20170221.0     NaN         NaN
#
#    매출액(최저)(원)  매출액(중앙값)(원)  매출액 최근 추정일자  매출액(Fwd.12M)(원)  매출액(Fwd.24M)(원)  \
# 0         NaN          NaN          NaN              NaN              NaN
# 1         NaN          NaN          NaN              NaN              NaN
# 2         NaN          NaN          NaN              NaN              NaN
# 3         NaN          NaN          NaN              NaN              NaN
# 4         NaN          NaN          NaN              NaN              NaN
#
#    매출액(LTM.12M)(원)
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df_etf_const.head()
# Out:
#          date    ETF코드       ETF명   구성종목코드    구성종목  주식수(계약수)        금액  \
# 0  2025-01-02  A069500  KODEX 200             원화현금       NaN   9945243
# 1  2025-01-02  A069500  KODEX 200  A000080   하이트진로      47.0    914620
# 2  2025-01-02  A069500  KODEX 200  A000100    유한양행      91.0  10765300
# 3  2025-01-02  A069500  KODEX 200  A000120  CJ대한통운      17.0   1429700
# 4  2025-01-02  A069500  KODEX 200  A000150      두산      11.0   2915000
#
#    금액기준 구성비중(%)
# 0          0.62
# 1          0.06
# 2          0.67
# 3          0.09
# 4          0.18

# %% [markdown]
# ## Filtered loading examples
#
# `fn_dg6_ingest` supports filtering by `codes` (ticker), `items` (columns), and `date_from`/`date_to`.

# %%
# Samsung Electronics adjusted close, 2024 only
fn_ds["ohlcv"].load(
    codes=["A005930"],
    items=["수정주가(원)"],
    date_from="2024-01-01",
    date_to="2024-12-31",
)
# Out:
#           코드   코드명        date  수정주가(원)
# 0    A005930  삼성전자  2024-01-02  79600.0
# 1    A005930  삼성전자  2024-01-03  77000.0
# 2    A005930  삼성전자  2024-01-04  76600.0
# 3    A005930  삼성전자  2024-01-05  76600.0
# 4    A005930  삼성전자  2024-01-08  76500.0
# ..       ...   ...         ...      ...
# 239  A005930  삼성전자  2024-12-23  53500.0
# 240  A005930  삼성전자  2024-12-24  54400.0
# 241  A005930  삼성전자  2024-12-26  53600.0
# 242  A005930  삼성전자  2024-12-27  53700.0
# 243  A005930  삼성전자  2024-12-30  53200.0
#
# [244 rows x 4 columns]

# %%
# KODEX 200 ETF constituents, latest date
fn_ds["etf_const"].load(date_from="2026-02-06")
# Out:
#            date    ETF코드       ETF명   구성종목코드       구성종목  주식수(계약수)        금액  \
# 0    2026-02-06  A069500  KODEX 200  A377300      카카오페이      42.0   2725800
# 1    2026-02-06  A069500  KODEX 200  A383220        F&F      21.0   1533000
# 2    2026-02-06  A069500  KODEX 200  A373220   LG에너지솔루션      74.0  28490000
# 3    2026-02-06  A069500  KODEX 200  A375500      DL이앤씨      44.0   1982200
# 4    2026-02-06  A069500  KODEX 200  A352820        하이브      32.0  11376000
# ..          ...      ...        ...      ...        ...       ...       ...
# 196  2026-02-06  A069500  KODEX 200  A000100       유한양행      90.0   9432000
# 197  2026-02-06  A069500  KODEX 200  A454910     두산로보틱스      29.0   2949300
# 198  2026-02-06  A069500  KODEX 200  A457190  이수스페셜티케미컬      30.0   3000000
# 199  2026-02-06  A069500  KODEX 200  A450080     에코프로머티      38.0   2394000
# 200  2026-02-06  A069500  KODEX 200  A443060  HD현대마린솔루션      22.0   3610200
#
#      금액기준 구성비중(%)
# 0            0.07
# 1            0.04
# 2            0.76
# 3            0.05
# 4            0.30
# ..            ...
# 196          0.25
# 197          0.08
# 198          0.08
# 199          0.06
# 200          0.10
#
# [201 rows x 8 columns]

# %% [markdown]
# ## FnGuide metadata / lineage

# %%
fn_ds["ohlcv"].load_meta()
# Out:
#   table_name                                        source_file  \
# 0    default  dataguide_kse+kosdaq_ohlcv_from(20160101)_to(2...
# 1    default  dataguide_kse+kosdaq_ohlcv_from(20160101)_to(2...
# 2    default  dataguide_kse+kosdaq_ohlcv_from(20160101)_to(2...
# 3    default  dataguide_kse+kosdaq_ohlcv_from(20160101)_to(2...
# 4    default  dataguide_kse+kosdaq_ohlcv_from(20160101)_to(2...
# 5    default  dataguide_kse+kosdaq_ohlcv_from(20160101)_to(2...
#
#                                          source_hash  source_last_updated  \
# 0  523e45d81c505847b44929c1b2b4c806e08d3a68327db3...  2026-02-07 15:46:56
# 1  523e45d81c505847b44929c1b2b4c806e08d3a68327db3...  2026-02-07 15:46:56
# 2  523e45d81c505847b44929c1b2b4c806e08d3a68327db3...  2026-02-07 15:46:56
# 3  523e45d81c505847b44929c1b2b4c806e08d3a68327db3...  2026-02-07 15:46:56
# 4  523e45d81c505847b44929c1b2b4c806e08d3a68327db3...  2026-02-07 15:46:56
# 5  523e45d81c505847b44929c1b2b4c806e08d3a68327db3...  2026-02-07 15:46:56
#
#    detected_format       아이템코드     아이템명 아이템명_normalized   유형 집계주기 frequency  \
# 0  timeseries_wide  S410000650  수정시가(원)         수정시가(원)  SSC   일간        일간
# 1  timeseries_wide  S410000660  수정고가(원)         수정고가(원)  SSC   일간        일간
# 2  timeseries_wide  S410000670  수정저가(원)         수정저가(원)  SSC   일간        일간
# 3  timeseries_wide  S410000700  수정주가(원)         수정주가(원)  SSC   일간        일간
# 4  timeseries_wide  S41000080F   거래량(주)          거래량(주)  SSC   일간        일간
# 5  timeseries_wide  S410000900  거래대금(원)         거래대금(원)  SSC   일간        일간
#
#   period_start      period_end unit_original  unit_multiplier  \
# 0     20160101  최근일자(20260206)             원                1
# 1     20160101  최근일자(20260206)             원                1
# 2     20160101  최근일자(20260206)             원                1
# 3     20160101  최근일자(20260206)             원                1
# 4     20160101  최근일자(20260206)           NaN                1
# 5     20160101  최근일자(20260206)             원                1
#
#   non_business_days include_weekends  entities_total  entities_dropped  \
# 0                제외               제외            4071              1000
# 1                제외               제외            4071              1000
# 2                제외               제외            4071              1000
# 3                제외               제외            4071              1000
# 4                제외               제외            4071              1000
# 5                제외               제외            4071              1000
#
#                 processed_at
# 0  2026-02-12T05:10:21+00:00
# 1  2026-02-12T05:10:21+00:00
# 2  2026-02-12T05:10:21+00:00
# 3  2026-02-12T05:10:21+00:00
# 4  2026-02-12T05:10:21+00:00
# 5  2026-02-12T05:10:21+00:00
